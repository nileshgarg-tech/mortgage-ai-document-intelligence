# %% [markdown]
# <a href="https://colab.research.google.com/github/nileshgarg-tech/mortgage-ai-document-intelligence/blob/main/Introduction_to_Pandas_Beginner's_Guide_Car_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# Pandas is an open source python library which contains data structures and data manipulation tools designed to make data cleaning and analysis fast and convenient in python.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008. It introduces two fundamental data structures: Series and DataFrame, which allow data to be organized, manipulated, and analyzed in a tabular format similar to spreadsheets or databases.
#
# <b><u>Reasons why Datascience professionals are highly dependent on Pandas.</u></b>
#
# 1. Pandas simplifies the process of data handling and manipulation, allowing its users to clean, preprocess, and transform data.
# 2. It offers powerful tools for data analysis and exploration.
# 3. It provides functions for aggregating data, computing descriptive statistics, handling time series data, and working with categorical and textual data.
# 4. It excels at data integration and preparation. We can easily load data from different sources (such as CSV, Excel, SQL databases, and more), merge or join datasets, and perform data transformations before further analysis.
#
# <h4>Installation</h4>
#
# To install Pandas, you can execute the command mentioned below in your terminal or command prompt:

# %%
#!pip install pandas

# %% [markdown]
# ### What do we learn in this segment?
#
# Pandas is very vast and there is so much more to explore. But as a beginner, in order to understand the essence of this library, one needs to atleast practice the following steps and these will be covered in this segment.
#
# 1. Import Pandas library
# 2. Data types
# 3. Reading and writing Data
# 4. Data Exploration and cleaning
# 5. Data Manipulation
# 6. Data aggregation and grouping

# %% [markdown]
# <h3>1. Import pandas library</h3>
#
# The initial step is to import the pandas library in order to use its functions. Normally pandas will be referred as pd (abbreviated form)

# %%
import pandas as pd

# %% [markdown]
# Now that we have imported the pandas library and henceforth it will be referred as pd. Lets move on to its datatypes.
#
# <h3>2. Data types</h3>
#
# * Pandas series - which is a one-dimensional data
# * Pandas Dataframe - which is a two-dimensional dataset
#
# you can create a Series using pd.Series() and passing it a Python list.

# %%
colors = pd.Series(['Blue', 'Red', 'Orange','Yellow'])
colors
# Out:
# 0      Blue
# 1       Red
# 2    Orange
# 3    Yellow
# dtype: object

# %%
bikes = pd.Series(['Yamaha','Honda','TVS','Vespa'])
bikes
# Out:
# 0    Yamaha
# 1     Honda
# 2       TVS
# 3     Vespa
# dtype: object

# %% [markdown]
# Let us use the above mentioned Series objects to create a DataFrame.

# %%
vehicle_df = pd.DataFrame({"Vehicle type": bikes,
                         "Color spec": colors})
vehicle_df
# Out:
#   Vehicle type Color spec
# 0       Yamaha       Blue
# 1        Honda        Red
# 2          TVS     Orange
# 3        Vespa     Yellow

# %% [markdown]
# Now let us explore few of the built-in function in the dataframe object.

# %%
#prints the datatypes of the columns present in the dataframe.
#Note : column with any datatype can be added to the dataframe.
vehicle_df.dtypes
# Out:
# Vehicle type    object
# Color spec      object
# dtype: object

# %%
#Displays the colulmns present in the dataframe.
vehicle_df.columns
# Out:
# Index(['Vehicle type', 'Color spec'], dtype='object')

# %% [markdown]
# One can access the cars dataset from Kaggle's website using the following link
#
# [Used Car Price Prediction Dataset](https://www.kaggle.com/datasets/taeefnajib/used-car-price-prediction-dataset)

# %% [markdown]
# So now we have learnt to create a series and dataframe object.
#
# <h3>Reading Data</h3>
#
# Now lets see how to import data from a csv or excel file and perform further operations.
#
# 1. To read a csv file, we should use read_csv option in pandas.
# 2. To read an excel file, read_excel option should be used.
#
# Note:
# The csv file given here is being downloaded from "Kaggle" website.

# %%
car_data = pd.read_csv("/content/used_cars.csv")
car_data
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# 0     E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1          Gasoline                               3.8L V6 24V GDI DOHC
# 2          Gasoline                                     3.5 Liter DOHC
# 3            Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4          Gasoline                         2.0L I4 16V GDI DOHC Turbo
# ...             ...                                                ...
# 4004       Gasoline                   6.0L W12 48V PDI DOHC Twin Turbo
# 4005       Gasoline      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006            NaN                                           Electric
# 4007       Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008       Gasoline       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission                 ext_col  int_col  \
# 0                           6-Speed A/T                   Black    Black
# 1                     8-Speed Automatic         Moonlight Cloud     Gray
# 2                             Automatic                    Blue    Black
# 3                           7-Speed A/T                   Black    Black
# 4                     8-Speed Automatic  Glacier White Metallic    Black
# ...                                 ...                     ...      ...
# 4004  8-Speed Automatic with Auto-Shift                   C / C  Hotspur
# 4005     Transmission w/Dual Shift Mode                   Black    Black
# 4006                          Automatic                   Black    Black
# 4007                                A/T                    Blue    Black
# 4008                                A/T                    Gray    Brown
#
#                                     accident clean_title     price
# 0     At least 1 accident or damage reported         Yes   $10,300
# 1     At least 1 accident or damage reported         Yes   $38,005
# 2                              None reported         NaN   $54,598
# 3                              None reported         Yes   $15,500
# 4                              None reported         NaN   $34,999
# ...                                      ...         ...       ...
# 4004                           None reported         Yes  $349,950
# 4005                           None reported         Yes   $53,900
# 4006                           None reported         NaN   $90,998
# 4007                           None reported         Yes   $62,999
# 4008  At least 1 accident or damage reported         Yes   $40,000
#
# [4009 rows x 12 columns]

# %% [markdown]
# <h3>3. Data Exploration and Cleaning</h3>
#
# One of the first things you'll want to do after you import some data into a pandas DataFrame is to start exploring it.
#
# Data cleaning deals with handing missing values
#
# pandas has many built in functions which allow you to quickly get information about a DataFrame.
#
# Let's explore some using the car_sales DataFrame.

# %%
#Displays the first 5 columns
car_data.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999

# %%
#Upon mentioning the number columns to be displayed, this head method will retieve the given count of rows.
car_data.head(10)
# Out:
#       brand                            model  model_year       milage  \
# 0      Ford  Utility Police Interceptor Base        2013   51,000 mi.
# 1   Hyundai                     Palisade SEL        2021   34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022   22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015   88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021    9,835 mi.
# 5     Acura                         ILX 2.4L        2016  136,397 mi.
# 6      Audi             S3 2.0T Premium Plus        2017   84,000 mi.
# 7       BMW                           740 iL        2001  242,000 mi.
# 8     Lexus                   RC 350 F Sport        2021   23,436 mi.
# 9     Tesla          Model X Long Range Plus        2020   34,000 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
# 5       Gasoline                                          2.4 Liter
# 6       Gasoline       292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 7       Gasoline       282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 8       Gasoline      311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 9            NaN        534.0HP Electric Motor Electric Fuel System
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
# 5                  F                  Silver  Ebony.
# 6        6-Speed A/T                    Blue   Black
# 7                A/T                   Green   Green
# 8        6-Speed A/T                   Black   Black
# 9                A/T                   Black   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999
# 5                           None reported         NaN  $14,798
# 6                           None reported         Yes  $31,000
# 7                           None reported         Yes   $7,300
# 8                           None reported         Yes  $41,927
# 9                           None reported         Yes  $69,950

# %%
#Likewise, we can see the last 5 records with the below given function
car_data.tail()
# Out:
#         brand                 model  model_year      milage fuel_type  \
# 4004  Bentley  Continental GT Speed        2023     714 mi.  Gasoline
# 4005     Audi  S4 3.0T Premium Plus        2022  10,900 mi.  Gasoline
# 4006  Porsche                Taycan        2022   2,116 mi.       NaN
# 4007     Ford          F-150 Raptor        2020  33,000 mi.  Gasoline
# 4008      BMW          X3 xDrive30i        2020  43,000 mi.  Gasoline
#
#                                              engine  \
# 4004               6.0L W12 48V PDI DOHC Twin Turbo
# 4005  349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006                                       Electric
# 4007  450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008   248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission ext_col  int_col  \
# 4004  8-Speed Automatic with Auto-Shift   C / C  Hotspur
# 4005     Transmission w/Dual Shift Mode   Black    Black
# 4006                          Automatic   Black    Black
# 4007                                A/T    Blue    Black
# 4008                                A/T    Gray    Brown
#
#                                     accident clean_title     price
# 4004                           None reported         Yes  $349,950
# 4005                           None reported         Yes   $53,900
# 4006                           None reported         NaN   $90,998
# 4007                           None reported         Yes   $62,999
# 4008  At least 1 accident or damage reported         Yes   $40,000

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %% [markdown]
# Info() will display the brief summary of the dataframe such as no of rows, total number of columns, datatype, column type(NULL o Non-NULL), memory usage per column. This will help in assessing the overall structure of the dataframe.

# %%
# Returns the dimensions of the dataframe
car_data.shape
# Out:
# (4009, 12)

# %% [markdown]
# This dataframe contains 4009 rows and 12 columns.

# %%
#Gives the data type of each columns
car_data.dtypes
# Out:
# brand           object
# model           object
# model_year       int64
# milage          object
# fuel_type       object
# engine          object
# transmission    object
# ext_col         object
# int_col         object
# accident        object
# clean_title     object
# price           object
# dtype: object

# %% [markdown]
# First, I'll clean the 'milage' and 'price' columns by removing non-numeric characters like ' mi.', ',', and '$'. Then, I'll convert them to a float data type.

# %%
# Remove ' mi.', '$', and commas, then convert to float
car_data['milage'] = car_data['milage'].str.replace(' mi.', '', regex=False).str.replace(',', '', regex=False).astype(float)
car_data['price'] = car_data['price'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(float)

# Verify types and data
print(car_data.dtypes)
display(car_data[['milage', 'price']].head())
# Out:
# brand            object
# model            object
# model_year        int64
# milage          float64
# fuel_type        object
# engine           object
# transmission     object
# ext_col          object
# int_col          object
# accident         object
# clean_title      object
# price           float64
# dtype: object
#     milage    price
# 0  51000.0  10300.0
# 1  34742.0  38005.0
# 2  22372.0  54598.0
# 3  88900.0  15500.0
# 4   9835.0  34999.0

# %%
#Detects the sum of all null values prsent in the dataframe.
car_data.isna().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %% [markdown]
# So we have found out how much na or null values are present in the dataframe. Now its time to handle these null values.
# We can either fill the values with suitable alternate values or drop the null values.
# This can be achieved with the following functions.
# 1. fillna() - Fill the null values with suitable alternate values. (0 or mean of the column)
# 2. dropna() - drop the null values.
#
# The decision to fill or drop should taken wisely considering the usage of the column and the contribution of it to the dataset. If the colulmn containing null values is the most important one and if the insights are derived from that particular column, then it would be better choice to drop the value. Because, whatever data we fill will be based on our assumption, it won't be accurate. So it is better to derive proper insight with right data even if it is available in less number.

# %%
#Now we will drop the null values in the car data dataframe

car_data = car_data.dropna()

car_data.isna().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %% [markdown]
# After dropping the null values, the dataset now has 0 null values.

# %% [markdown]
# The Describe function provides a quick statistical overview of the numerical columns present in the Data Frame.

# %%
car_data.describe()
# Out:
#         model_year         milage         price
# count  3269.000000    3269.000000  3.269000e+03
# mean   2014.601407   72126.951973  4.124113e+04
# std       6.152181   53387.413623  8.304604e+04
# min    1974.000000     100.000000  2.000000e+03
# 25%    2011.000000   30450.000000  1.550000e+04
# 50%    2016.000000   62930.000000  2.800000e+04
# 75%    2019.000000  102750.000000  4.650000e+04
# max    2024.000000  405000.000000  2.954083e+06

# %% [markdown]
# * Count - Gives the number of non-null values
# * mean - The average of the values present in the column
# * std - Standard deviation value for the data present in the column
# * min - minimum value present in the given column
# * max - maximum value present in the given column
# * 25% - 25 percentile (the value at which 25% of the answers lie below that value and 75% of the answers lie above that value.)
# * 50% - 50 percentile (Also known as the Median. The median cuts the data set in half.  Half of the answers lie below the median and half lie above the median.)
# * 75% - 75 percentile (Also known as the third, or upper, quartile. The 75th percentile is the value at which 25% of the answers lie above that value and 75% of the answers lie below that value. Above the 75th or below the 25th percentile)

# %% [markdown]
# <h3>4. Data Manipulation</h3>
#
#  Perform filtering, sorting, and selection operations on the data comes under data manipulation.
#  Through this we will be able to understand the pattern of the data to some extent.  data).

# %%
#Filtering rows based on selling price greater than 100k USD
filtered_data = car_data[car_data['price'] > 100000]
filtered_data
# Out:
#               brand                    model  model_year   milage fuel_type  \
# 11            Aston  Martin DBS Superleggera        2019  22770.0  Gasoline
# 16    Mercedes-Benz              Metris Base        2021   1685.0  Gasoline
# 71          Bentley       Continental GT W12        2017  14684.0  Gasoline
# 93            Aston  Martin DBS Superleggera        2021   2165.0  Gasoline
# 152         Ferrari                  FF Base        2016  19987.0  Gasoline
# ...             ...                      ...         ...      ...       ...
# 3878    Lamborghini          Huracan LP610-4        2015  34152.0  Gasoline
# 3959      Chevrolet  Corvette Stingray w/2LT        2023   2058.0  Gasoline
# 3964        Porsche              911 Carrera        2022   2950.0  Gasoline
# 4002  Mercedes-Benz        AMG GLS 63 4MATIC        2023   2000.0    Hybrid
# 4004        Bentley     Continental GT Speed        2023    714.0  Gasoline
#
#                                                  engine  \
# 11        715.0HP 5.2L 12 Cylinder Engine Gasoline Fuel
# 16                           2.0L I4 16V GDI DOHC Turbo
# 71        582.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 93                     5.2L V12 48V GDI DOHC Twin Turbo
# 152       651.0HP 6.3L 12 Cylinder Engine Gasoline Fuel
# ...                                                 ...
# 3878      602.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 3959       490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3964  379.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 4002  603.0HP 4.0L 8 Cylinder Engine Gasoline/Mild E...
# 4004                   6.0L W12 48V PDI DOHC Twin Turbo
#
#                            transmission ext_col  int_col       accident  \
# 11                          8-Speed A/T  Silver    Black  None reported
# 16                    9-Speed Automatic    Gray    White  None reported
# 71                          8-Speed A/T   White    White  None reported
# 93                    8-Speed Automatic   Black    Black  None reported
# 152                         7-Speed A/T   Black    Brown  None reported
# ...                                 ...     ...      ...            ...
# 3878                        7-Speed A/T    Blue      Red  None reported
# 3959                                A/T    Gray    Black  None reported
# 3964                        8-Speed A/T   Green    Black  None reported
# 4002                        9-Speed A/T    Gray    Beige  None reported
# 4004  8-Speed Automatic with Auto-Shift   C / C  Hotspur  None reported
#
#      clean_title     price
# 11           Yes  184606.0
# 16           Yes  250000.0
# 71           Yes  130000.0
# 93           Yes  279950.0
# 152          Yes  149900.0
# ...          ...       ...
# 3878         Yes  185500.0
# 3959         Yes  101999.0
# 3964         Yes  131000.0
# 4002         Yes  175000.0
# 4004         Yes  349950.0
#
# [160 rows x 12 columns]

# %%
#sorting based on Model Year
sorted_data = car_data.sort_values(by='model_year', ascending=True)
sorted_data
# Out:
#        brand                  model  model_year    milage fuel_type  \
# 855     Ford                 Bronco        1974    6217.0         –
# 1088   Mazda        MX-5 Miata Base        1992  125800.0         –
# 257   Toyota      Land Cruiser Base        1993  231500.0         –
# 3469    Ford  F-250 XL SuperCab H/D        1993  115000.0         –
# 3922   Mazda             Protege DX        1993   94200.0         –
# ...      ...                    ...         ...       ...       ...
# 3309     GMC     Sierra 2500 Denali        2024    2043.0  Gasoline
# 556    Mazda          CX-90 Premium        2024    3880.0  Gasoline
# 443      BMW                  M3 CS        2024     456.0  Gasoline
# 3529   Lexus        NX 350h Premium        2024     300.0    Hybrid
# 1691     BMW                  M3 CS        2024     124.0  Gasoline
#
#                                                  engine  \
# 855                                                   –
# 1088                                                  –
# 257                                                   –
# 3469                                                  –
# 3922                                                  –
# ...                                                 ...
# 3309       401.0HP 6.6L 8 Cylinder Engine Gasoline Fuel
# 556                                                2.5L
# 443   543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 3529  240.0HP 2.5L 4 Cylinder Engine Gas/Electric Hy...
# 1691  543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
#
#                         transmission                ext_col int_col  \
# 855                                –     Dark Gray Metallic       –
# 1088                     5-Speed M/T                    Red   Black
# 257                              A/T                  White    Gray
# 3469                             A/T                    Red    Gray
# 3922                             A/T                   Gray       –
# ...                              ...                    ...     ...
# 3309                    10-Speed A/T                  White   Black
# 556                8-Speed Automatic  Machine Gray Metallic   Black
# 443   Transmission w/Dual Shift Mode                  Black   Black
# 3529                             A/T                  Black   Black
# 1691  Transmission w/Dual Shift Mode                  Green   Black
#
#                                     accident clean_title     price
# 855                            None reported         Yes  115000.0
# 1088                           None reported         Yes   11500.0
# 257                            None reported         Yes   29500.0
# 3469                           None reported         Yes   21900.0
# 3922  At least 1 accident or damage reported         Yes    2500.0
# ...                                      ...         ...       ...
# 3309                           None reported         Yes   81500.0
# 556                            None reported         Yes   52991.0
# 443                            None reported         Yes  128995.0
# 3529                           None reported         Yes   50999.0
# 1691                           None reported         Yes  145000.0
#
# [3269 rows x 12 columns]

# %% [markdown]
# <h3>5. Data Aggregation and Grouping</h3>
#
#   Aggregate data using functions like sum, mean, count, etc., and perform grouping operation.

# %%
#Find the sum of all the values present in the sellingprice column
print(f"{car_data['price'].sum()} dollars ")
# Out:
# 134817242.0 dollars

# %%
#find the mean, median and mode of the sellingprice column
print(f"{car_data['price'].mean()} dollars ")
# Out:
# 41241.12633832976 dollars

# %%
#find the count of the rows for which the selling price is greater than 100000
car_count = car_data[car_data['price'] > 100000].count()
print(car_count)
# Out:
# brand           160
# model           160
# model_year      160
# milage          160
# fuel_type       160
# engine          160
# transmission    160
# ext_col         160
# int_col         160
# accident        160
# clean_title     160
# price           160
# dtype: int64

# %%
#groupby the data based on the model.
grouped_data = car_data.groupby('brand')
grouped_data.first()
# Out:
#                                          model  model_year    milage  \
# brand
# Acura                            RL Technology        2010   97700.0
# Alfa                    Romeo Stelvio Ti Sport        2020   18665.0
# Aston                  Martin DBS Superleggera        2019   22770.0
# Audi                      S3 2.0T Premium Plus        2017   84000.0
# BMW                                     740 iL        2001  242000.0
# Bentley                   Continental GTC Base        2011   20200.0
# Bugatti                Veyron 16.4 Grand Sport        2011    6330.0
# Buick                       Verano Convenience        2013   68325.0
# Cadillac                    CT5 Premium Luxury        2023    6090.0
# Chevrolet                              S-10 LS        2000  133510.0
# Chrysler                           300 Touring        2009  134602.0
# Dodge                           Challenger SXT        2013   61074.0
# FIAT                         124 Spider Abarth        2017   45000.0
# Ferrari                                FF Base        2016   19987.0
# Ford           Utility Police Interceptor Base        2013   51000.0
# GMC                               Acadia SLT-1        2012  116226.0
# Genesis                       G90 3.3T Premium        2021    9950.0
# Honda                                 S2000 CR        2008   82323.0
# Hummer                                 H2 Base        2005  110900.0
# Hyundai                           Palisade SEL        2021   34742.0
# INFINITI                      Q50 Hybrid Sport        2015   88900.0
# Jaguar                                F-TYPE R        2018   35250.0
# Jeep                     New Compass Trailhawk        2017  119000.0
# Kia                                 Sorento SX        2011  171000.0
# Lamborghini                      Gallardo Base        2007   38800.0
# Land                             Rover LR4 HSE        2013   79800.0
# Lexus                           RC 350 F Sport        2021   23436.0
# Lincoln                    Aviator Reserve AWD        2022   18196.0
# Lotus                           Evora 400 Base        2017   19650.0
# MINI             Convertible John Cooper Works        2017   24280.0
# Maserati                        Quattroporte S        2019   23230.0
# Maybach                           Type 57 Base        2004   34254.0
# Mazda                       CX-9 Grand Touring        2021   46707.0
# McLaren                            570S Spider        2020    8700.0
# Mercedes-Benz                      Metris Base        2021    1685.0
# Mercury                          Marauder Base        2004   56600.0
# Mitsubishi                Lancer Evolution GSR        2012   33000.0
# Nissan                         350Z Enthusiast        2003   74000.0
# Plymouth                          Prowler Base        2001   22300.0
# Pontiac                          Firebird Base        1999  158000.0
# Porsche               Cayenne Platinum Edition        2017   73043.0
# RAM                   ProMaster 3500 High Roof        2021  147834.0
# Rolls-Royce    Phantom Drophead Coupe Drophead        2013    2958.0
# Saab                                    9-3 SE        2002   77200.0
# Saturn                                Sky Base        2008   15020.0
# Scion                                  tC Base        2013  177600.0
# Subaru                        Forester Premium        2021   42125.0
# Suzuki                                SX4 Base        2013   99982.0
# Toyota                       Supra 3.0 Premium        2021   12500.0
# Volkswagen     Golf R 20th Anniversary Edition        2023     633.0
# Volvo                  XC90 Hybrid T8 R-Design        2018   40000.0
# smart                              ForTwo Pure        2008   61595.0
#
#                     fuel_type  \
# brand
# Acura                Gasoline
# Alfa                 Gasoline
# Aston                Gasoline
# Audi                 Gasoline
# BMW                  Gasoline
# Bentley         E85 Flex Fuel
# Bugatti              Gasoline
# Buick           E85 Flex Fuel
# Cadillac             Gasoline
# Chevrolet       E85 Flex Fuel
# Chrysler             Gasoline
# Dodge                Gasoline
# FIAT                 Gasoline
# Ferrari              Gasoline
# Ford            E85 Flex Fuel
# GMC                  Gasoline
# Genesis              Gasoline
# Honda                Gasoline
# Hummer               Gasoline
# Hyundai              Gasoline
# INFINITI               Hybrid
# Jaguar               Gasoline
# Jeep                 Gasoline
# Kia                  Gasoline
# Lamborghini          Gasoline
# Land                 Gasoline
# Lexus                Gasoline
# Lincoln              Gasoline
# Lotus                Gasoline
# MINI                 Gasoline
# Maserati             Gasoline
# Maybach              Gasoline
# Mazda                Gasoline
# McLaren              Gasoline
# Mercedes-Benz        Gasoline
# Mercury              Gasoline
# Mitsubishi           Gasoline
# Nissan               Gasoline
# Plymouth             Gasoline
# Pontiac              Gasoline
# Porsche              Gasoline
# RAM                  Gasoline
# Rolls-Royce          Gasoline
# Saab                 Gasoline
# Saturn               Gasoline
# Scion                Gasoline
# Subaru               Gasoline
# Suzuki               Gasoline
# Toyota               Gasoline
# Volkswagen           Gasoline
# Volvo          Plug-In Hybrid
# smart                Gasoline
#
#                                                           engine  \
# brand
# Acura              300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# Alfa                                  2.0L I4 16V GDI SOHC Turbo
# Aston              715.0HP 5.2L 12 Cylinder Engine Gasoline Fuel
# Audi                292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# BMW                 282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# Bentley        552.0HP 6.0L 12 Cylinder Engine Flex Fuel Capa...
# Bugatti                         8.0L W16 64V GDI DOHC Twin Turbo
# Buick          180.0HP 2.4L 4 Cylinder Engine Flex Fuel Capab...
# Cadillac            237.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Chevrolet      120.0HP 2.2L 4 Cylinder Engine Flex Fuel Capab...
# Chrysler           250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# Dodge              305.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# FIAT                164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# Ferrari            651.0HP 6.3L 12 Cylinder Engine Gasoline Fuel
# Ford           300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# GMC                288.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# Genesis            365.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# Honda               237.0HP 2.2L 4 Cylinder Engine Gasoline Fuel
# Hummer              325.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# Hyundai                                     3.8L V6 24V GDI DOHC
# INFINITI       354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# Jaguar              550.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# Jeep                180.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# Kia                276.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# Lamborghini        493.0HP 5.0L 10 Cylinder Engine Gasoline Fuel
# Land                375.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# Lexus              311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# Lincoln            400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# Lotus              400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# MINI                228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Maserati           424.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# Maybach            543.0HP 5.5L 12 Cylinder Engine Gasoline Fuel
# Mazda                                 2.5L I4 16V GDI DOHC Turbo
# McLaren             562.0HP 3.8L 8 Cylinder Engine Gasoline Fuel
# Mercedes-Benz                         2.0L I4 16V GDI DOHC Turbo
# Mercury             302.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# Mitsubishi          291.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Nissan             287.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# Plymouth           253.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# Pontiac            200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# Porsche            300.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# RAM                                        3.6L V6 24V MPFI DOHC
# Rolls-Royce                                6.8L V12 48V GDI DOHC
# Saab                205.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Saturn              173.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# Scion               180.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# Subaru                                      2.5L H4 16V GDI DOHC
# Suzuki              150.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Toyota         382.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# Volkswagen          315.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Volvo          400.0HP 2.0L 4 Cylinder Engine Plug-In Electri...
# smart                70.0HP 1.0L 3 Cylinder Engine Gasoline Fuel
#
#                                     transmission                 ext_col  \
# brand
# Acura             Transmission w/Dual Shift Mode                    Blue
# Alfa                           8-Speed Automatic   Lunare White Metallic
# Aston                                8-Speed A/T                  Silver
# Audi                                 6-Speed A/T                    Blue
# BMW                                          A/T                   Green
# Bentley                              6-Speed A/T                   Black
# Bugatti        7-Speed Automatic with Auto-Shift                   White
# Buick             Transmission w/Dual Shift Mode                  Silver
# Cadillac                                     A/T                   White
# Chevrolet                                    A/T                    Blue
# Chrysler          Transmission w/Dual Shift Mode                    Blue
# Dodge                                        A/T                   Black
# FIAT                                 6-Speed M/T                    Gray
# Ferrari                              7-Speed A/T                   Black
# Ford                                 6-Speed A/T                   Black
# GMC                                  6-Speed A/T                   Black
# Genesis                              8-Speed A/T                  Silver
# Honda                                6-Speed M/T                   Black
# Hummer                                       A/T                    Gray
# Hyundai                        8-Speed Automatic         Moonlight Cloud
# INFINITI                             7-Speed A/T                   Black
# Jaguar                               8-Speed A/T                   Green
# Jeep                                         A/T                     Red
# Kia                                          A/T                   Black
# Lamborghini       Transmission w/Dual Shift Mode                  Orange
# Land                                         A/T                   White
# Lexus                                6-Speed A/T                   Black
# Lincoln           Transmission w/Dual Shift Mode                   Black
# Lotus                                6-Speed M/T                  Silver
# MINI                                 6-Speed A/T                   Black
# Maserati                             8-Speed A/T                   Black
# Maybach                              5-Speed A/T                   Brown
# Mazda                          6-Speed Automatic   Sonic Silver Metallic
# McLaren           Transmission w/Dual Shift Mode                   Black
# Mercedes-Benz                  9-Speed Automatic                    Gray
# Mercury            Transmission Overdrive Switch                  Silver
# Mitsubishi                           5-Speed M/T                   Black
# Nissan                               6-Speed M/T                  Purple
# Plymouth                             4-Speed A/T                    Blue
# Pontiac                              4-Speed A/T                   White
# Porsche                              8-Speed A/T                   White
# RAM                            6-Speed Automatic  Bright White Clearcoat
# Rolls-Royce                    8-Speed Automatic                  Yellow
# Saab                                 5-Speed M/T                   Black
# Saturn                                       A/T                  Silver
# Scion                                6-Speed A/T                  Silver
# Subaru                             Automatic CVT    Crystal Black Silica
# Suzuki                                       M/T                  Orange
# Toyota                                       A/T                  Yellow
# Volkswagen                           6-Speed M/T                   White
# Volvo             Transmission w/Dual Shift Mode                   Black
# smart                                5-Speed A/T                    Blue
#
#               int_col                                accident clean_title  \
# brand
# Acura           Beige                           None reported         Yes
# Alfa              Ice                           None reported         Yes
# Aston           Black                           None reported         Yes
# Audi            Black                           None reported         Yes
# BMW             Green                           None reported         Yes
# Bentley         Black                           None reported         Yes
# Bugatti         White                           None reported         Yes
# Buick            Gray                           None reported         Yes
# Cadillac        Beige                           None reported         Yes
# Chevrolet       Black                           None reported         Yes
# Chrysler        Black                           None reported         Yes
# Dodge            Gray                           None reported         Yes
# FIAT            Black  At least 1 accident or damage reported         Yes
# Ferrari         Brown                           None reported         Yes
# Ford            Black  At least 1 accident or damage reported         Yes
# GMC             Black                           None reported         Yes
# Genesis          Blue                           None reported         Yes
# Honda           Black                           None reported         Yes
# Hummer          Black                           None reported         Yes
# Hyundai          Gray  At least 1 accident or damage reported         Yes
# INFINITI        Black                           None reported         Yes
# Jaguar          Black                           None reported         Yes
# Jeep            Black                           None reported         Yes
# Kia             Black                           None reported         Yes
# Lamborghini    Orange                           None reported         Yes
# Land            Black                           None reported         Yes
# Lexus           Black                           None reported         Yes
# Lincoln         Brown                           None reported         Yes
# Lotus             Red                           None reported         Yes
# MINI            Black  At least 1 accident or damage reported         Yes
# Maserati        Black                           None reported         Yes
# Maybach             –                           None reported         Yes
# Mazda           Black  At least 1 accident or damage reported         Yes
# McLaren         Black                           None reported         Yes
# Mercedes-Benz   White                           None reported         Yes
# Mercury         Black                           None reported         Yes
# Mitsubishi      Black                           None reported         Yes
# Nissan              –                           None reported         Yes
# Plymouth         Gray                           None reported         Yes
# Pontiac         Black  At least 1 accident or damage reported         Yes
# Porsche         Black                           None reported         Yes
# RAM             Black                           None reported         Yes
# Rolls-Royce         –                           None reported         Yes
# Saab            Beige                           None reported         Yes
# Saturn            Red                           None reported         Yes
# Scion           Black  At least 1 accident or damage reported         Yes
# Subaru          Black                           None reported         Yes
# Suzuki           Gray  At least 1 accident or damage reported         Yes
# Toyota          Black                           None reported         Yes
# Volkswagen      Black                           None reported         Yes
# Volvo           Black                           None reported         Yes
# smart            Gray                           None reported         Yes
#
#                    price
# brand
# Acura            10995.0
# Alfa             35645.0
# Aston           184606.0
# Audi             31000.0
# BMW               7300.0
# Bentley          79950.0
# Bugatti        1950995.0
# Buick            11995.0
# Cadillac         46900.0
# Chevrolet         4500.0
# Chrysler          7500.0
# Dodge            16800.0
# FIAT             22500.0
# Ferrari         149900.0
# Ford             10300.0
# GMC               7900.0
# Genesis          53950.0
# Honda            28500.0
# Hummer           19500.0
# Hyundai          38005.0
# INFINITI         15500.0
# Jaguar           68750.0
# Jeep             15900.0
# Kia               5999.0
# Lamborghini     100000.0
# Land             29990.0
# Lexus            41927.0
# Lincoln          62000.0
# Lotus            69250.0
# MINI             29000.0
# Maserati         44999.0
# Maybach          64250.0
# Mazda            32541.0
# McLaren         185000.0
# Mercedes-Benz   250000.0
# Mercury          23000.0
# Mitsubishi       34999.0
# Nissan           11000.0
# Plymouth         28500.0
# Pontiac           2500.0
# Porsche          30990.0
# RAM              32662.0
# Rolls-Royce     488880.0
# Saab              7500.0
# Saturn           18500.0
# Scion             7100.0
# Subaru           27899.0
# Suzuki            6900.0
# Toyota           53500.0
# Volkswagen       47999.0
# Volvo            42000.0
# smart             5000.0
