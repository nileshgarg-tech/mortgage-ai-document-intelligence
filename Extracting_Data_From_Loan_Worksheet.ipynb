# %% [markdown]
# <a href="https://colab.research.google.com/github/nileshgarg-tech/mortgage-ai-document-intelligence/blob/main/Extracting_Data_From_Loan_Worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Environment Setup
# %%capture
# !pip install pymupdf

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3b260e2-f734-477c-bd91-d053b2b71189" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3b260e2-f734-477c-bd91-d053b2b71189">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Loading the FIle
import fitz
doc = fitz.open("LenderFeesWorksheetNew.pdf")

# %%
## File Page Count
doc.page_count
# Out:
# 1

# %%
doc.metadata
# Out:
# {'format': 'PDF 1.3',
#  'title': 'POINT Document',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'creator': '',
#  'producer': 'Amyuni PDF Converter version 4.5.2.3',
#  'creationDate': "D:20151001155359-07'00'",
#  'modDate': '',
#  'trapped': '',
#  'encryption': None}

# %%
# Getting raw text from pdf
page = doc[0]
text = page.get_text("text")
print(text[:500])
# Out:
# Your actual rate, payment, and cost could be higher. Get an official Loan Estimate before choosing a loan.
# Fee Details and Summary
# Applicants:
# Application No:
# Date Prepared:
# Loan Program:
# Prepared By:
# THIS IS NOT A GOOD FAITH ESTIMATE (GFE). This "Fees Worksheet" is provided for informational purposes ONLY, to assist
# you in determining an estimate of cash that may be required to close and an estimate of your proposed monthly mortgage
# payment. Actual charges may be more or less, and your transac

# %%
page = doc[0]
words = page.get_text("words")
for word in words[:5]:
    print(word)
# Out:
# (36.0, 26.097490310668945, 60.943878173828125, 38.3197021484375, 'Your', 0, 0, 0)
# (63.95075607299805, 26.097490310668945, 95.60314178466797, 38.3197021484375, 'actual', 0, 0, 1)
# (98.61001586914062, 26.097490310668945, 121.74352264404297, 38.3197021484375, 'rate,', 0, 0, 2)
# (124.75039672851562, 26.097490310668945, 172.82777404785156, 38.3197021484375, 'payment,', 0, 0, 3)
# (175.8346710205078, 26.097490310668945, 195.30154418945312, 38.3197021484375, 'and', 0, 0, 4)

# %%
structured_list = []
for word in words:
  dic = {}
  dic['text'] = word[4]
  dic['bbox'] = list(word[0:4])
  structured_list.append(dic)
structured_list[-5:]
# Out:
# [{'text': 'x',
#   'bbox': [417.8839111328125,
#    436.16455078125,
#    421.88140869140625,
#    445.094970703125]},
#  {'text': '12',
#   'bbox': [424.1750183105469,
#    436.16455078125,
#    433.07745361328125,
#    445.094970703125]},
#  {'text': 'mth(s)',
#   'bbox': [435.3710632324219,
#    436.16455078125,
#    458.0809020996094,
#    445.094970703125]},
#  {'text': '$',
#   'bbox': [478.79998779296875,
#    436.16455078125,
#    483.2452087402344,
#    445.094970703125]},
#  {'text': '475.00',
#   'bbox': [501.1199951171875,
#    436.16455078125,
#    525.6087036132812,
#    445.094970703125]}]

# %%
import json

# Convert the structured_list to a JSON string
json_data = json.dumps(structured_list, indent=4)

# Define the filename for the JSON output
output_filename = "structured_list.json"

# Save the JSON data to a file
with open(output_filename, "w") as f:
    f.write(json_data)

print(f"Structured list successfully saved to {output_filename}")
# Out:
# Structured list successfully saved to structured_list.json
